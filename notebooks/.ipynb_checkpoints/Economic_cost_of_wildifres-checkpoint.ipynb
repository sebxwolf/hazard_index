# %% [markdown]
# <h1>Estimating potential economic losses from wildfires<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# ### Goal:
#
# Given a hazard index indicating the probability of wildfires, come up with metrics that indicate potential economic losses in the endangered areas
#
# ### Strategy:
#
# - import hazard index
#     - import and study the raw data
#     - pick area of interest
# - import data on the topography from openstreetmaps, study the individual parts
#     - extract builing footprints
#     - points of interest
#     - network centrality
#     - landuse
# - convert into metrics correlated with economic losses
#     - size of building (area)
#     - category of point of interest (value)
#     - centrality of location (real estate price level)
#     - landuse category (high-value (winery etc) or farmland)
# - spatial merge the hazard index grid with the points and polygons with economic measures attached to them
# - aggregate economic measures by pixel grid
# - combine economic measures into an index
# - analyse the resuly

# %% [markdown]
# # Notebook preparation

# %%
# Make sure script changes take effect within this session
# %load_ext autoreload
# %autoreload 2

# %%
# import some useful packages for this analysis
from setup import *
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %% [markdown]
# # Import hazard index

# %% [markdown]
# ## import and study the raw data
# ### Load the json from kepler.gl

# %%
# read in the main datafile
json_file = json.load(open('../data/keplergl.json'))

# %% [markdown]
# ### Convert the json file to geopandas dfs
#
# Unfortunately, the json file can't be read directly into a GeoDataFrame using geopandas, because it contains five different datasets, and because the individual datasets' structure was not recognised by geopandas. Therefore, I have to implement a manual conversion of the json file into five dataframes, holding the individual layers.
#
# The hazard data is in the first dataset, which I save in df1. The remaining dfs hold the shapes of the fires.

# %%
json_file
# Out:
# {'datasets': [{'version': 'v1',
#    'data': {'id': '24645u33j',
#     'label': 'hc17_ZZfnd25_N1k_1000_I1.geojson',
#     'color': [143, 47, 191],
#     'allData': [[{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 0},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.0677943024656, 42.0517121830832],
#           [-121.0677943024656, 42.0414448987341],
#           [-121.0369924494183, 42.0414448987341],
#           [-121.0369924494183, 42.0517121830832],
#           [-121.0677943024656, 42.0517121830832]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 1},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.09859615551288, 42.0414448987341],
#           [-121.09859615551288, 42.031177614385],
#           [-121.08832887116378, 42.031177614385],
#           [-121.08832887116378, 42.0414448987341],
#           [-121.09859615551288, 42.0414448987341]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 2},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.08832887116378, 42.0414448987341],
#           [-121.08832887116378, 42.031177614385],
#           [-121.07806158681468, 42.031177614385],
#           [-121.07806158681468, 42.0414448987341],
#           [-121.08832887116378, 42.0414448987341]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 4, 'index': 3},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.07806158681468, 42.0414448987341],
#           [-121.07806158681468, 42.031177614385],
#           [-121.0369924494183, 42.031177614385],
#           [-121.0369924494183, 42.0414448987341],
#           [-121.07806158681468, 42.0414448987341]]]}},
#       '2019-10-01 00:00',
#       4],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 4},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.0369924494183, 42.0414448987341],
#           [-121.0369924494183, 42.031177614385],
#           [-120.98565602767282, 42.031177614385],
#           [-120.98565602767282, 42.0414448987341],
#           [-121.0369924494183, 42.0414448987341]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 5},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.98565602767282, 42.0414448987341],
#           [-120.98565602767282, 42.031177614385],
#           [-120.97538874332372, 42.031177614385],
#           [-120.97538874332372, 42.0414448987341],
#           [-120.98565602767282, 42.0414448987341]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 6},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.96512145897464, 42.0414448987341],
#           [-120.96512145897464, 42.031177614385],
#           [-120.94458689027644, 42.031177614385],
#           [-120.94458689027644, 42.0414448987341],
#           [-120.96512145897464, 42.0414448987341]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 7},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-124.00423762630714, 42.031177614385],
#           [-124.00423762630714, 42.02091033003591],
#           [-123.99397034195805, 42.02091033003591],
#           [-123.99397034195805, 42.031177614385],
#           [-124.00423762630714, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 8},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.99397034195805, 42.031177614385],
#           [-123.99397034195805, 42.02091033003591],
#           [-123.95290120456167, 42.02091033003591],
#           [-123.95290120456167, 42.031177614385],
#           [-123.99397034195805, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 9},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.95290120456167, 42.031177614385],
#           [-123.95290120456167, 42.02091033003591],
#           [-123.91183206716528, 42.02091033003591],
#           [-123.91183206716528, 42.031177614385],
#           [-123.95290120456167, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 4, 'index': 10},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.91183206716528, 42.031177614385],
#           [-123.91183206716528, 42.02091033003591],
#           [-123.90156478281618, 42.02091033003591],
#           [-123.90156478281618, 42.031177614385],
#           [-123.91183206716528, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       4],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 11},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.90156478281618, 42.031177614385],
#           [-123.90156478281618, 42.02091033003591],
#           [-123.8604956454198, 42.02091033003591],
#           [-123.8604956454198, 42.031177614385],
#           [-123.90156478281618, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 12},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.8604956454198, 42.031177614385],
#           [-123.8604956454198, 42.02091033003591],
#           [-123.83996107672161, 42.02091033003591],
#           [-123.83996107672161, 42.031177614385],
#           [-123.8604956454198, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 13},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.83996107672161, 42.031177614385],
#           [-123.83996107672161, 42.02091033003591],
#           [-123.82969379237251, 42.02091033003591],
#           [-123.82969379237251, 42.031177614385],
#           [-123.83996107672161, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 14},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.11913072421108, 42.031177614385],
#           [-121.11913072421108, 42.02091033003591],
#           [-121.09859615551288, 42.02091033003591],
#           [-121.09859615551288, 42.031177614385],
#           [-121.11913072421108, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 15},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.09859615551288, 42.031177614385],
#           [-121.09859615551288, 42.02091033003591],
#           [-121.08832887116378, 42.02091033003591],
#           [-121.08832887116378, 42.031177614385],
#           [-121.09859615551288, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 5, 'index': 16},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.08832887116378, 42.031177614385],
#           [-121.08832887116378, 42.02091033003591],
#           [-121.02672516506921, 42.02091033003591],
#           [-121.02672516506921, 42.031177614385],
#           [-121.08832887116378, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       5],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 6, 'index': 17},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.02672516506921, 42.031177614385],
#           [-121.02672516506921, 42.02091033003591],
#           [-120.98565602767282, 42.02091033003591],
#           [-120.98565602767282, 42.031177614385],
#           [-121.02672516506921, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       6],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 4, 'index': 18},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.98565602767282, 42.031177614385],
#           [-120.98565602767282, 42.02091033003591],
#           [-120.97538874332372, 42.02091033003591],
#           [-120.97538874332372, 42.031177614385],
#           [-120.98565602767282, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       4],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 19},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.97538874332372, 42.031177614385],
#           [-120.97538874332372, 42.02091033003591],
#           [-120.96512145897464, 42.02091033003591],
#           [-120.96512145897464, 42.031177614385],
#           [-120.97538874332372, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 4, 'index': 20},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.96512145897464, 42.031177614385],
#           [-120.96512145897464, 42.02091033003591],
#           [-120.95485417462554, 42.02091033003591],
#           [-120.95485417462554, 42.031177614385],
#           [-120.96512145897464, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       4],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 21},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.95485417462554, 42.031177614385],
#           [-120.95485417462554, 42.02091033003591],
#           [-120.94458689027644, 42.02091033003591],
#           [-120.94458689027644, 42.031177614385],
#           [-120.95485417462554, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 22},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.94458689027644, 42.031177614385],
#           [-120.94458689027644, 42.02091033003591],
#           [-120.91378503722915, 42.02091033003591],
#           [-120.91378503722915, 42.031177614385],
#           [-120.94458689027644, 42.031177614385]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 23},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-124.00423762630714, 42.02091033003591],
#           [-124.00423762630714, 42.000375761337715],
#           [-123.99397034195805, 42.000375761337715],
#           [-123.99397034195805, 42.02091033003591],
#           [-124.00423762630714, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 4, 'index': 24},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.99397034195805, 42.02091033003591],
#           [-123.99397034195805, 42.01064304568681],
#           [-123.97343577325987, 42.01064304568681],
#           [-123.97343577325987, 42.02091033003591],
#           [-123.99397034195805, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       4],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 5, 'index': 25},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.97343577325987, 42.02091033003591],
#           [-123.97343577325987, 42.01064304568681],
#           [-123.96316848891077, 42.01064304568681],
#           [-123.96316848891077, 42.02091033003591],
#           [-123.97343577325987, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       5],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 6, 'index': 26},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.96316848891077, 42.02091033003591],
#           [-123.96316848891077, 42.01064304568681],
#           [-123.95290120456167, 42.01064304568681],
#           [-123.95290120456167, 42.02091033003591],
#           [-123.96316848891077, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       6],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 7, 'index': 27},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.95290120456167, 42.02091033003591],
#           [-123.95290120456167, 42.01064304568681],
#           [-123.93236663586347, 42.01064304568681],
#           [-123.93236663586347, 42.02091033003591],
#           [-123.95290120456167, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       7],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 8, 'index': 28},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.93236663586347, 42.02091033003591],
#           [-123.93236663586347, 42.01064304568681],
#           [-123.92209935151438, 42.01064304568681],
#           [-123.92209935151438, 42.02091033003591],
#           [-123.93236663586347, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       8],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 9, 'index': 29},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.92209935151438, 42.02091033003591],
#           [-123.92209935151438, 42.01064304568681],
#           [-123.91183206716528, 42.01064304568681],
#           [-123.91183206716528, 42.02091033003591],
#           [-123.92209935151438, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       9],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 10, 'index': 30},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.91183206716528, 42.02091033003591],
#           [-123.91183206716528, 42.01064304568681],
#           [-123.89129749846708, 42.01064304568681],
#           [-123.89129749846708, 42.02091033003591],
#           [-123.91183206716528, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       10],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 11, 'index': 31},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.89129749846708, 42.02091033003591],
#           [-123.89129749846708, 42.01064304568681],
#           [-123.8707629297689, 42.01064304568681],
#           [-123.8707629297689, 42.02091033003591],
#           [-123.89129749846708, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       11],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 10, 'index': 32},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.8707629297689, 42.02091033003591],
#           [-123.8707629297689, 42.01064304568681],
#           [-123.8604956454198, 42.01064304568681],
#           [-123.8604956454198, 42.02091033003591],
#           [-123.8707629297689, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       10],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 8, 'index': 33},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.8604956454198, 42.02091033003591],
#           [-123.8604956454198, 42.01064304568681],
#           [-123.83996107672161, 42.01064304568681],
#           [-123.83996107672161, 42.02091033003591],
#           [-123.8604956454198, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       8],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 5, 'index': 34},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.83996107672161, 42.02091033003591],
#           [-123.83996107672161, 42.01064304568681],
#           [-123.82969379237251, 42.01064304568681],
#           [-123.82969379237251, 42.02091033003591],
#           [-123.83996107672161, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       5],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 35},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.82969379237251, 42.02091033003591],
#           [-123.82969379237251, 42.01064304568681],
#           [-123.81942650802341, 42.01064304568681],
#           [-123.81942650802341, 42.02091033003591],
#           [-123.82969379237251, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 36},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.67975794527372, 42.02091033003591],
#           [-122.67975794527372, 42.01064304568681],
#           [-122.66949066092462, 42.01064304568681],
#           [-122.66949066092462, 42.02091033003591],
#           [-122.67975794527372, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 37},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.66949066092462, 42.02091033003591],
#           [-122.66949066092462, 42.01064304568681],
#           [-122.63868880787733, 42.01064304568681],
#           [-122.63868880787733, 42.02091033003591],
#           [-122.66949066092462, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 38},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.63868880787733, 42.02091033003591],
#           [-122.63868880787733, 42.01064304568681],
#           [-122.62842152352823, 42.01064304568681],
#           [-122.62842152352823, 42.02091033003591],
#           [-122.63868880787733, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 39},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.36147213045173, 42.02091033003591],
#           [-122.36147213045173, 42.01064304568681],
#           [-122.35120484610263, 42.01064304568681],
#           [-122.35120484610263, 42.02091033003591],
#           [-122.36147213045173, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 40},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.35120484610263, 42.02091033003591],
#           [-122.35120484610263, 42.01064304568681],
#           [-122.34093756175353, 42.01064304568681],
#           [-122.34093756175353, 42.02091033003591],
#           [-122.35120484610263, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 41},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.34093756175353, 42.02091033003591],
#           [-122.34093756175353, 42.01064304568681],
#           [-122.33067027740445, 42.01064304568681],
#           [-122.33067027740445, 42.02091033003591],
#           [-122.34093756175353, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 42},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.33067027740445, 42.02091033003591],
#           [-122.33067027740445, 42.01064304568681],
#           [-122.32040299305535, 42.01064304568681],
#           [-122.32040299305535, 42.02091033003591],
#           [-122.33067027740445, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 43},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.32040299305535, 42.02091033003591],
#           [-122.32040299305535, 42.01064304568681],
#           [-122.31013570870626, 42.01064304568681],
#           [-122.31013570870626, 42.02091033003591],
#           [-122.32040299305535, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 44},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.16019986160747, 42.02091033003591],
#           [-121.16019986160747, 42.01064304568681],
#           [-121.14993257725837, 42.01064304568681],
#           [-121.14993257725837, 42.02091033003591],
#           [-121.16019986160747, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 45},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.12939800856017, 42.02091033003591],
#           [-121.12939800856017, 42.01064304568681],
#           [-121.11913072421108, 42.01064304568681],
#           [-121.11913072421108, 42.02091033003591],
#           [-121.12939800856017, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 46},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.11913072421108, 42.02091033003591],
#           [-121.11913072421108, 42.01064304568681],
#           [-121.09859615551288, 42.01064304568681],
#           [-121.09859615551288, 42.02091033003591],
#           [-121.11913072421108, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 5, 'index': 47},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.09859615551288, 42.02091033003591],
#           [-121.09859615551288, 42.01064304568681],
#           [-121.08832887116378, 42.01064304568681],
#           [-121.08832887116378, 42.02091033003591],
#           [-121.09859615551288, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       5],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 6, 'index': 48},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.08832887116378, 42.02091033003591],
#           [-121.08832887116378, 42.01064304568681],
#           [-121.07806158681468, 42.01064304568681],
#           [-121.07806158681468, 42.02091033003591],
#           [-121.08832887116378, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       6],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 7, 'index': 49},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.07806158681468, 42.02091033003591],
#           [-121.07806158681468, 42.01064304568681],
#           [-121.02672516506921, 42.01064304568681],
#           [-121.02672516506921, 42.02091033003591],
#           [-121.07806158681468, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       7],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 8, 'index': 50},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.02672516506921, 42.02091033003591],
#           [-121.02672516506921, 42.01064304568681],
#           [-121.01645788072011, 42.01064304568681],
#           [-121.01645788072011, 42.02091033003591],
#           [-121.02672516506921, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       8],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 8, 'index': 51},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.98565602767282, 42.02091033003591],
#           [-120.98565602767282, 42.01064304568681],
#           [-120.97538874332372, 42.01064304568681],
#           [-120.97538874332372, 42.02091033003591],
#           [-120.98565602767282, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       8],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 6, 'index': 52},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.97538874332372, 42.02091033003591],
#           [-120.97538874332372, 42.01064304568681],
#           [-120.96512145897464, 42.01064304568681],
#           [-120.96512145897464, 42.02091033003591],
#           [-120.97538874332372, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       6],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 5, 'index': 53},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.96512145897464, 42.02091033003591],
#           [-120.96512145897464, 42.01064304568681],
#           [-120.95485417462554, 42.01064304568681],
#           [-120.95485417462554, 42.000375761337715],
#           [-120.94458689027644, 42.000375761337715],
#           [-120.94458689027644, 41.99010847698862],
#           [-120.93431960592734, 41.99010847698862],
#           [-120.93431960592734, 41.979841192639526],
#           [-120.90351775288005, 41.979841192639526],
#           [-120.90351775288005, 42.000375761337715],
#           [-120.91378503722915, 42.000375761337715],
#           [-120.91378503722915, 42.01064304568681],
#           [-120.94458689027644, 42.01064304568681],
#           [-120.94458689027644, 42.02091033003591],
#           [-120.96512145897464, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       5],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 4, 'index': 54},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.94458689027644, 42.02091033003591],
#           [-120.94458689027644, 42.01064304568681],
#           [-120.92405232157824, 42.01064304568681],
#           [-120.92405232157824, 42.02091033003591],
#           [-120.94458689027644, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       4],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 55},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.92405232157824, 42.02091033003591],
#           [-120.92405232157824, 42.01064304568681],
#           [-120.91378503722915, 42.01064304568681],
#           [-120.91378503722915, 42.02091033003591],
#           [-120.92405232157824, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 56},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.91378503722915, 42.02091033003591],
#           [-120.91378503722915, 42.01064304568681],
#           [-120.90351775288005, 42.01064304568681],
#           [-120.90351775288005, 42.02091033003591],
#           [-120.91378503722915, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 57},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.90351775288005, 42.02091033003591],
#           [-120.90351775288005, 42.01064304568681],
#           [-120.89325046853095, 42.01064304568681],
#           [-120.89325046853095, 42.02091033003591],
#           [-120.90351775288005, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 58},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-124.02477219500534, 42.01064304568681],
#           [-124.02477219500534, 41.99010847698862],
#           [-124.00423762630714, 41.99010847698862],
#           [-124.00423762630714, 42.01064304568681],
#           [-124.02477219500534, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 6, 'index': 59},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.97343577325987, 42.01064304568681],
#           [-123.97343577325987, 41.99010847698862],
#           [-123.96316848891077, 41.99010847698862],
#           [-123.96316848891077, 42.01064304568681],
#           [-123.97343577325987, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       6],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 8, 'index': 60},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.96316848891077, 42.01064304568681],
#           [-123.96316848891077, 42.000375761337715],
#           [-123.95290120456167, 42.000375761337715],
#           [-123.95290120456167, 42.01064304568681],
#           [-123.96316848891077, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       8],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 12, 'index': 61},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.92209935151438, 42.01064304568681],
#           [-123.92209935151438, 42.000375761337715],
#           [-123.91183206716528, 42.000375761337715],
#           [-123.91183206716528, 42.01064304568681],
#           [-123.92209935151438, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       12],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 15, 'index': 62},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.91183206716528, 42.01064304568681],
#           [-123.91183206716528, 42.000375761337715],
#           [-123.90156478281618, 42.000375761337715],
#           [-123.90156478281618, 42.01064304568681],
#           [-123.91183206716528, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       15],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 17, 'index': 63},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.90156478281618, 42.01064304568681],
#           [-123.90156478281618, 42.000375761337715],
#           [-123.89129749846708, 42.000375761337715],
#           [-123.89129749846708, 42.01064304568681],
#           [-123.90156478281618, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       17],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 18, 'index': 64},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.89129749846708, 42.01064304568681],
#           [-123.89129749846708, 42.000375761337715],
#           [-123.8707629297689, 42.000375761337715],
#           [-123.8707629297689, 42.01064304568681],
#           [-123.89129749846708, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       18],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 16, 'index': 65},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.8707629297689, 42.01064304568681],
#           [-123.8707629297689, 42.000375761337715],
#           [-123.8604956454198, 42.000375761337715],
#           [-123.8604956454198, 42.01064304568681],
#           [-123.8707629297689, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       16],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 14, 'index': 66},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.8604956454198, 42.01064304568681],
#           [-123.8604956454198, 42.000375761337715],
#           [-123.8502283610707, 42.000375761337715],
#           [-123.8502283610707, 42.01064304568681],
#           [-123.8604956454198, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       14],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 13, 'index': 67},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.8502283610707, 42.01064304568681],
#           [-123.8502283610707, 42.000375761337715],
#           [-123.83996107672161, 42.000375761337715],
#           [-123.83996107672161, 42.01064304568681],
#           [-123.8502283610707, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       13],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 11, 'index': 68},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.83996107672161, 42.01064304568681],
#           [-123.83996107672161, 42.000375761337715],
#           [-123.82969379237251, 42.000375761337715],
#           [-123.82969379237251, 42.01064304568681],
#           [-123.83996107672161, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       11],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 6, 'index': 69},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.82969379237251, 42.01064304568681],
#           [-123.82969379237251, 42.000375761337715],
#           [-123.81942650802341, 42.000375761337715],
#           [-123.81942650802341, 42.01064304568681],
#           [-123.82969379237251, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       6],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 70},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.81942650802341, 42.01064304568681],
#           [-123.81942650802341, 42.000375761337715],
#           [-123.79889193932522, 42.000375761337715],
#           [-123.79889193932522, 42.01064304568681],
#           [-123.81942650802341, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 71},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.79889193932522, 42.01064304568681],
#           [-123.79889193932522, 42.000375761337715],
#           [-123.78862465497613, 42.000375761337715],
#           [-123.78862465497613, 42.01064304568681],
#           [-123.79889193932522, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 72},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.69002522962282, 42.01064304568681],
#           [-122.69002522962282, 42.000375761337715],
#           [-122.67975794527372, 42.000375761337715],
#           [-122.67975794527372, 42.01064304568681],
#           [-122.69002522962282, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 73},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.67975794527372, 42.01064304568681],
#           [-122.67975794527372, 42.000375761337715],
#           [-122.66949066092462, 42.000375761337715],
#           [-122.66949066092462, 42.01064304568681],
#           [-122.67975794527372, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 5, 'index': 74},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.66949066092462, 42.01064304568681],
#           [-122.66949066092462, 42.000375761337715],
#           [-122.65922337657553, 42.000375761337715],
#           [-122.65922337657553, 42.01064304568681],
#           [-122.66949066092462, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       5],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 7, 'index': 75},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.65922337657553, 42.01064304568681],
#           [-122.65922337657553, 42.000375761337715],
#           [-122.63868880787733, 42.000375761337715],
#           [-122.63868880787733, 42.01064304568681],
#           [-122.65922337657553, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       7],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 4, 'index': 76},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.63868880787733, 42.01064304568681],
#           [-122.63868880787733, 42.000375761337715],
#           [-122.62842152352823, 42.000375761337715],
#           [-122.62842152352823, 42.01064304568681],
#           [-122.63868880787733, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       4],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 77},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.62842152352823, 42.01064304568681],
#           [-122.62842152352823, 42.000375761337715],
#           [-122.61815423917915, 42.000375761337715],
#           [-122.61815423917915, 42.01064304568681],
#           [-122.62842152352823, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 78},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.4436104052445, 42.01064304568681],
#           [-122.4436104052445, 42.000375761337715],
#           [-122.42307583654632, 42.000375761337715],
#           [-122.42307583654632, 42.01064304568681],
#           [-122.4436104052445, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 79},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.42307583654632, 42.01064304568681],
#           [-122.42307583654632, 42.000375761337715],
#           [-122.41280855219722, 42.000375761337715],
#           [-122.41280855219722, 42.01064304568681],
#           [-122.42307583654632, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 80},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.41280855219722, 42.01064304568681],
#           [-122.41280855219722, 42.000375761337715],
#           [-122.39227398349902, 42.000375761337715],
#           [-122.39227398349902, 42.01064304568681],
#           [-122.41280855219722, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 81},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.39227398349902, 42.01064304568681],
#           [-122.39227398349902, 42.000375761337715],
#           [-122.38200669914993, 42.000375761337715],
#           [-122.38200669914993, 42.01064304568681],
#           [-122.39227398349902, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 82},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.38200669914993, 42.01064304568681],
#           [-122.38200669914993, 42.000375761337715],
#           [-122.36147213045173, 42.000375761337715],
#           [-122.36147213045173, 42.01064304568681],
#           [-122.38200669914993, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 7, 'index': 83},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.36147213045173, 42.01064304568681],
#           [-122.36147213045173, 42.000375761337715],
#           [-122.35120484610263, 42.000375761337715],
#           [-122.35120484610263, 42.01064304568681],
#           [-122.36147213045173, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       7],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 13, 'index': 84},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.35120484610263, 42.01064304568681],
#           [-122.35120484610263, 42.000375761337715],
#           [-122.34093756175353, 42.000375761337715],
#           [-122.34093756175353, 42.01064304568681],
#           [-122.35120484610263, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       13],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 15, 'index': 85},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.34093756175353, 42.01064304568681],
#           [-122.34093756175353, 42.000375761337715],
#           [-122.33067027740445, 42.000375761337715],
#           [-122.33067027740445, 42.01064304568681],
#           [-122.34093756175353, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       15],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 13, 'index': 86},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.33067027740445, 42.01064304568681],
#           [-122.33067027740445, 42.000375761337715],
#           [-122.32040299305535, 42.000375761337715],
#           [-122.32040299305535, 42.01064304568681],
#           [-122.33067027740445, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       13],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 6, 'index': 87},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.32040299305535, 42.01064304568681],
#           [-122.32040299305535, 42.000375761337715],
#           [-122.31013570870626, 42.000375761337715],
#           [-122.31013570870626, 42.01064304568681],
#           [-122.32040299305535, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       6],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 88},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-122.31013570870626, 42.01064304568681],
#           [-122.31013570870626, 42.000375761337715],
#           [-122.28960114000806, 42.000375761337715],
#           [-122.28960114000806, 42.01064304568681],
#           [-122.31013570870626, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 1, 'index': 89},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.17046714595655, 42.01064304568681],
#           [-121.17046714595655, 42.000375761337715],
#           [-121.16019986160747, 42.000375761337715],
#           [-121.16019986160747, 42.01064304568681],
#           [-121.17046714595655, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       1],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 3, 'index': 90},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.16019986160747, 42.01064304568681],
#           [-121.16019986160747, 42.000375761337715],
#           [-121.14993257725837, 42.000375761337715],
#           [-121.14993257725837, 42.01064304568681],
#           [-121.16019986160747, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       3],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 4, 'index': 91},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.14993257725837, 42.01064304568681],
#           [-121.14993257725837, 42.000375761337715],
#           [-121.12939800856017, 42.000375761337715],
#           [-121.12939800856017, 42.01064304568681],
#           [-121.14993257725837, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       4],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 6, 'index': 92},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.12939800856017, 42.01064304568681],
#           [-121.12939800856017, 42.000375761337715],
#           [-121.11913072421108, 42.000375761337715],
#           [-121.11913072421108, 42.01064304568681],
#           [-121.12939800856017, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       6],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 7, 'index': 93},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.11913072421108, 42.01064304568681],
#           [-121.11913072421108, 42.000375761337715],
#           [-121.10886343986198, 42.000375761337715],
#           [-121.10886343986198, 42.01064304568681],
#           [-121.11913072421108, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       7],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 8, 'index': 94},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.10886343986198, 42.01064304568681],
#           [-121.10886343986198, 42.000375761337715],
#           [-121.09859615551288, 42.000375761337715],
#           [-121.09859615551288, 42.01064304568681],
#           [-121.10886343986198, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       8],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 9, 'index': 95},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-121.01645788072011, 42.02091033003591],
#           [-121.01645788072011, 42.01064304568681],
#           [-121.02672516506921, 42.01064304568681],
#           [-121.09859615551288, 42.01064304568681],
#           [-121.09859615551288, 42.000375761337715],
#           [-120.98565602767282, 42.000375761337715],
#           [-120.97538874332372, 42.000375761337715],
#           [-120.97538874332372, 42.01064304568681],
#           [-120.98565602767282, 42.01064304568681],
#           [-120.98565602767282, 42.02091033003591],
#           [-121.01645788072011, 42.02091033003591]]]}},
#       '2019-10-01 00:00',
#       9],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 8, 'index': 96},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.97538874332372, 42.01064304568681],
#           [-120.97538874332372, 42.000375761337715],
#           [-120.96512145897464, 42.000375761337715],
#           [-120.96512145897464, 42.01064304568681],
#           [-120.97538874332372, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       8],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 6, 'index': 97},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.96512145897464, 42.01064304568681],
#           [-120.96512145897464, 42.000375761337715],
#           [-120.95485417462554, 42.000375761337715],
#           [-120.95485417462554, 42.01064304568681],
#           [-120.96512145897464, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       6],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 4, 'index': 98},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.91378503722915, 42.01064304568681],
#           [-120.91378503722915, 42.000375761337715],
#           [-120.90351775288005, 42.000375761337715],
#           [-120.90351775288005, 42.01064304568681],
#           [-120.91378503722915, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       4],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 2, 'index': 99},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-120.90351775288005, 42.01064304568681],
#           [-120.90351775288005, 41.99010847698862],
#           [-120.89325046853095, 41.99010847698862],
#           [-120.89325046853095, 42.01064304568681],
#           [-120.90351775288005, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       2],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 4, 'index': 100},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-124.00423762630714, 42.000375761337715],
#           [-124.00423762630714, 41.99010847698862],
#           [-123.99397034195805, 41.99010847698862],
#           [-123.99397034195805, 42.000375761337715],
#           [-124.00423762630714, 42.000375761337715]]]}},
#       '2019-10-01 00:00',
#       4],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 9, 'index': 101},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.95290120456167, 42.01064304568681],
#           [-123.95290120456167, 42.000375761337715],
#           [-123.96316848891077, 42.000375761337715],
#           [-123.96316848891077, 41.99010847698862],
#           [-123.93236663586347, 41.99010847698862],
#           [-123.93236663586347, 42.000375761337715],
#           [-123.92209935151438, 42.000375761337715],
#           [-123.92209935151438, 42.01064304568681],
#           [-123.95290120456167, 42.01064304568681]]]}},
#       '2019-10-01 00:00',
#       9],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 10, 'index': 102},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.93236663586347, 42.000375761337715],
#           [-123.93236663586347, 41.99010847698862],
#           [-123.92209935151438, 41.99010847698862],
#           [-123.92209935151438, 42.000375761337715],
#           [-123.93236663586347, 42.000375761337715]]]}},
#       '2019-10-01 00:00',
#       10],
#      [{'type': 'Feature',
#        'properties': {'date': '2019-10-01 00:00', 'I1': 13, 'index': 103},
#        'geometry': {'type': 'Polygon',
#         'coordinates': [[[-123.92209935151438, 42.000375761337715],
# ...
#            [-121.69949323319821, 39.78832958765573],
#            [-121.6994649583025, 39.78832251452148]]],
#          [[[-121.5613341721689, 39.88716260453269],
#            [-121.56136270653474, 39.887160954922656],
#            [-121.56139559143446, 39.88716146007367],
#            [-121.5614330239165, 39.88716416640734],
#            [-121.56147391412884, 39.887169032819365],
#            [-121.56156053647351, 39.88718451412026],
#            [-121.5615953447782, 39.88719357027921],
#            [-121.56163022497084, 39.88720556402833],
#            [-121.56166504479792, 39.88722045016415],
#            [-121.56169964370638, 39.88723816028413],
#            [-121.56173389003419, 39.887258632773914],
#            [-121.56176753228324, 39.887281723095256],
#            [-121.56180034806603, 39.887307279052024],
#            [-121.56183207769915, 39.88733509882887],
#            [-121.56186286963415, 39.88736538156418],
#            [-121.56189195214802, 39.88739744070922],
#            [-121.5619190099974, 39.88743092921637],
#            [-121.56194371556649, 39.88746544219115],
#            [-121.56196577365138, 39.887500572088236],
#            [-121.56198487404076, 39.88753583050512],
#            [-121.56200076276532, 39.887570748356296],
#            [-121.56201323223927, 39.887604869442455],
#            [-121.56203615426233, 39.88768748631987],
#            [-121.56204243102472, 39.88772185297658],
#            [-121.5620455711681, 39.88775312082978],
#            [-121.56204558683454, 39.88778202632735],
#            [-121.56204240772945, 39.88780822686198],
#            [-121.56203602308094, 39.88783180753783],
#            [-121.56202642216827, 39.88785280454056],
#            [-121.56201179460984, 39.887874689542315],
#            [-121.56199270077846, 39.88789683825715],
#            [-121.56196956165654, 39.887918759785364],
#            [-121.5619430048559, 39.88793985718553],
#            [-121.56191373170121, 39.88795956049887],
#            [-121.56188271955621, 39.887977199446624],
#            [-121.56185093996238, 39.887992222655726],
#            [-121.56181930556384, 39.88800419919379],
#            [-121.56178008150641, 39.88801523249338],
#            [-121.56173746833484, 39.888023717708535],
#            [-121.56169596542537, 39.88802876858717],
#            [-121.56165929728478, 39.88802993376838],
#            [-121.5616430024112, 39.88802859566699],
#            [-121.56162773516945, 39.88802542156063],
#            [-121.56161345667704, 39.88802040352571],
#            [-121.56160012132077, 39.88801352566461],
#            [-121.5615761104858, 39.88799410942304],
#            [-121.56155517389371, 39.887966752449636],
#            [-121.5615400200504, 39.8879382077587],
#            [-121.56152576433858, 39.88790260660694],
#            [-121.56148164277774, 39.887756053272405],
#            [-121.5614594291807, 39.88769655618569],
#            [-121.56144525051879, 39.88766779422401],
#            [-121.5614298648651, 39.887642958355514],
#            [-121.56141301739304, 39.887621640475835],
#            [-121.56139455918789, 39.88760365799239],
#            [-121.5613659769492, 39.88758273799572],
#            [-121.56128763944609, 39.8875338147743],
#            [-121.5612687504631, 39.88751895862489],
#            [-121.56125480901997, 39.88750457957587],
#            [-121.56124305247809, 39.88748779336726],
#            [-121.56123286609423, 39.88746824684926],
#            [-121.56122439188965, 39.887446210181466],
#            [-121.56121777929953, 39.887422069289144],
#            [-121.56121061662601, 39.887369242637675],
#            [-121.56121208835843, 39.8873147840454],
#            [-121.56122184650113, 39.887264740889215],
#            [-121.56122957728485, 39.88724247675302],
#            [-121.56123903053333, 39.88722261374992],
#            [-121.56125000807872, 39.887205530953366],
#            [-121.56126240592938, 39.88719135804748],
#            [-121.56127608515483, 39.88718025269012],
#            [-121.56129092816525, 39.88717230909459],
#            [-121.56131020807256, 39.88716639562899],
#            [-121.5613341721689, 39.88716260453269]]]]}},
#       '{75E64DB8-9B75-4A68-BEDD-67CC62658E38}',
#       'Infrared Image',
#       'CABTU',
#       'CAPNF',
#       '2018-CABTU-016737',
#       'CAMP',
#       '11/12/2018 10:05:00 PM',
#       'null',
#       'CDF',
#       'Y',
#       'Y',
#       'null',
#       '2018',
#       '2018/11/13',
#       '6250',
#       'L6BH',
#       'null',
#       'null',
#       '016737',
#       'null',
#       'CA',
#       'N',
#       138127.03849]],
#     'fields': [{'name': '_geojson', 'type': 'geojson', 'format': ''},
#      {'name': 'irwinid', 'type': 'string', 'format': ''},
#      {'name': 'mapmethod', 'type': 'string', 'format': ''},
#      {'name': 'unitIDProt', 'type': 'string', 'format': ''},
#      {'name': 'unitIDOwn', 'type': 'string', 'format': ''},
#      {'name': 'incidentID', 'type': 'string', 'format': ''},
#      {'name': 'fireName', 'type': 'string', 'format': ''},
#      {'name': 'perDatTime', 'type': 'timestamp', 'format': 'M/D/YYYY H:m:s'},
#      {'name': 'comments', 'type': 'string', 'format': ''},
#      {'name': 'agency', 'type': 'string', 'format': ''},
#      {'name': 'active', 'type': 'string', 'format': ''},
#      {'name': 'latest', 'type': 'string', 'format': ''},
#      {'name': 'compParID', 'type': 'string', 'format': ''},
#      {'name': 'fireYear', 'type': 'integer', 'format': ''},
#      {'name': 'dateCrnt', 'type': 'date', 'format': 'YYYY/M/D'},
#      {'name': 'inciwebId', 'type': 'integer', 'format': ''},
#      {'name': 'firecode', 'type': 'string', 'format': ''},
#      {'name': 'mergeid', 'type': 'string', 'format': ''},
#      {'name': 'compfirecd', 'type': 'string', 'format': ''},
#      {'name': 'fireNum', 'type': 'integer', 'format': ''},
#      {'name': 'ComplexNm', 'type': 'string', 'format': ''},
#      {'name': 'state', 'type': 'string', 'format': ''},
#      {'name': 'inComplex', 'type': 'string', 'format': ''},
#      {'name': 'GISACRES', 'type': 'real', 'format': ''}]}}],
#  'config': {'version': 'v1',
#   'config': {'visState': {'filters': [{'dataId': ['24645u33j'],
#       'id': '5c51ov0jm',
#       'name': ['I1'],
#       'type': 'range',
#       'value': [1, 989],
#       'enlarged': False,
#       'plotType': 'histogram',
#       'yAxis': None},
#      {'dataId': ['24645u33j'],
#       'id': '9c925wo',
#       'name': ['date'],
#       'type': 'timeRange',
#       'value': [1569888000000, 1569972407000],
#       'enlarged': True,
#       'plotType': 'histogram',
#       'yAxis': None}],
#     'layers': [{'id': 'rx9m2pm',
#       'type': 'geojson',
#       'config': {'dataId': 'tzehl3l3d',
#        'label': 'CA_camp_20181112_2205',
#        'color': [21, 174, 180],
#        'columns': {'geojson': '_geojson'},
#        'isVisible': True,
#        'visConfig': {'opacity': 0.5,
#         'thickness': 0.5,
#         'strokeColor': [254, 210, 26],
#         'colorRange': {'name': 'Global Warming',
#          'type': 'sequential',
#          'category': 'Uber',
#          'colors': ['#5A1846',
#           '#900C3F',
#           '#C70039',
#           '#E3611C',
#           '#F1920E',
#           '#FFC300']},
#         'strokeColorRange': {'name': 'Global Warming',
#          'type': 'sequential',
#          'category': 'Uber',
#          'colors': ['#5A1846',
#           '#900C3F',
#           '#C70039',
#           '#E3611C',
#           '#F1920E',
#           '#FFC300']},
#         'radius': 10,
#         'sizeRange': [0, 10],
#         'radiusRange': [0, 50],
#         'heightRange': [0, 500],
#         'elevationScale': 5,
#         'stroked': True,
#         'filled': True,
#         'enable3d': False,
#         'wireframe': False},
#        'textLabel': [{'field': None,
#          'color': [255, 255, 255],
#          'size': 18,
#          'offset': [0, 0],
#          'anchor': 'start',
#          'alignment': 'center'}]},
#       'visualChannels': {'colorField': None,
#        'colorScale': 'quantile',
#        'sizeField': None,
#        'sizeScale': 'linear',
#        'strokeColorField': None,
#        'strokeColorScale': 'quantile',
#        'heightField': None,
#        'heightScale': 'linear',
#        'radiusField': None,
#        'radiusScale': 'linear'}},
#      {'id': 'f8gimag',
#       'type': 'geojson',
#       'config': {'dataId': '786hup2i',
#        'label': 'CA_mendocino_river_20180810_2113',
#        'color': [71, 211, 217],
#        'columns': {'geojson': '_geojson'},
#        'isVisible': True,
#        'visConfig': {'opacity': 0.5,
#         'thickness': 0.5,
#         'strokeColor': [254, 210, 26],
#         'colorRange': {'name': 'Global Warming',
#          'type': 'sequential',
#          'category': 'Uber',
#          'colors': ['#5A1846',
#           '#900C3F',
#           '#C70039',
#           '#E3611C',
#           '#F1920E',
#           '#FFC300']},
#         'strokeColorRange': {'name': 'Global Warming',
#          'type': 'sequential',
#          'category': 'Uber',
#          'colors': ['#5A1846',
#           '#900C3F',
#           '#C70039',
#           '#E3611C',
#           '#F1920E',
#           '#FFC300']},
#         'radius': 10,
#         'sizeRange': [0, 10],
#         'radiusRange': [0, 50],
#         'heightRange': [0, 500],
#         'elevationScale': 5,
#         'stroked': True,
#         'filled': True,
#         'enable3d': False,
#         'wireframe': False},
#        'textLabel': [{'field': None,
#          'color': [255, 255, 255],
#          'size': 18,
#          'offset': [0, 0],
#          'anchor': 'start',
#          'alignment': 'center'}]},
#       'visualChannels': {'colorField': None,
#        'colorScale': 'quantile',
#        'sizeField': None,
#        'sizeScale': 'linear',
#        'strokeColorField': None,
#        'strokeColorScale': 'quantile',
#        'heightField': None,
#        'heightScale': 'linear',
#        'radiusField': None,
#        'radiusScale': 'linear'}},
#      {'id': 'vxqtwyf',
#       'type': 'geojson',
#       'config': {'dataId': 'zbswxvdn',
#        'label': 'CA_mendocino_ranch_20180813_2334',
#        'color': [23, 184, 190],
#        'columns': {'geojson': '_geojson'},
#        'isVisible': True,
#        'visConfig': {'opacity': 0.5,
#         'thickness': 0.5,
#         'strokeColor': [246, 209, 138],
#         'colorRange': {'name': 'Global Warming',
#          'type': 'sequential',
#          'category': 'Uber',
#          'colors': ['#5A1846',
#           '#900C3F',
#           '#C70039',
#           '#E3611C',
#           '#F1920E',
#           '#FFC300']},
#         'strokeColorRange': {'name': 'Global Warming',
#          'type': 'sequential',
#          'category': 'Uber',
#          'colors': ['#5A1846',
#           '#900C3F',
#           '#C70039',
#           '#E3611C',
#           '#F1920E',
#           '#FFC300']},
#         'radius': 10,
#         'sizeRange': [0, 10],
#         'radiusRange': [0, 50],
#         'heightRange': [0, 500],
#         'elevationScale': 5,
#         'stroked': True,
#         'filled': True,
#         'enable3d': False,
#         'wireframe': False},
#        'textLabel': [{'field': None,
#          'color': [255, 255, 255],
#          'size': 18,
#          'offset': [0, 0],
#          'anchor': 'start',
#          'alignment': 'center'}]},
#       'visualChannels': {'colorField': None,
#        'colorScale': 'quantile',
#        'sizeField': None,
#        'sizeScale': 'linear',
#        'strokeColorField': None,
#        'strokeColorScale': 'quantile',
#        'heightField': None,
#        'heightScale': 'linear',
#        'radiusField': None,
#        'radiusScale': 'linear'}},
#      {'id': 'aqn78bk',
#       'type': 'geojson',
#       'config': {'dataId': 'z4h7l9e4a',
#        'label': 'CA_tubbs_20171010_2139_IR',
#        'color': [36, 115, 189],
#        'columns': {'geojson': '_geojson'},
#        'isVisible': True,
#        'visConfig': {'opacity': 0.5,
#         'thickness': 0.5,
#         'strokeColor': [255, 219, 51],
#         'colorRange': {'name': 'Global Warming',
#          'type': 'sequential',
#          'category': 'Uber',
#          'colors': ['#5A1846',
#           '#900C3F',
#           '#C70039',
#           '#E3611C',
#           '#F1920E',
#           '#FFC300']},
#         'strokeColorRange': {'name': 'Global Warming',
#          'type': 'sequential',
#          'category': 'Uber',
#          'colors': ['#5A1846',
#           '#900C3F',
#           '#C70039',
#           '#E3611C',
#           '#F1920E',
#           '#FFC300']},
#         'radius': 10,
#         'sizeRange': [0, 10],
#         'radiusRange': [0, 50],
#         'heightRange': [0, 500],
#         'elevationScale': 5,
#         'stroked': True,
#         'filled': True,
#         'enable3d': False,
#         'wireframe': False},
#        'textLabel': [{'field': None,
#          'color': [255, 255, 255],
#          'size': 18,
#          'offset': [0, 0],
#          'anchor': 'start',
#          'alignment': 'center'}]},
#       'visualChannels': {'colorField': None,
#        'colorScale': 'quantile',
#        'sizeField': None,
#        'sizeScale': 'linear',
#        'strokeColorField': None,
#        'strokeColorScale': 'quantile',
#        'heightField': None,
#        'heightScale': 'linear',
#        'radiusField': None,
#        'radiusScale': 'linear'}},
#      {'id': 'kmb3ka',
#       'type': 'geojson',
#       'config': {'dataId': '24645u33j',
#        'label': 'hc17_ZZfnd25_N1k_1000_I1',
#        'color': [246, 209, 138],
#        'columns': {'geojson': '_geojson'},
#        'isVisible': True,
#        'visConfig': {'opacity': 0.8,
#         'thickness': 0.5,
#         'strokeColor': [183, 136, 94],
#         'colorRange': {'name': 'ColorBrewer RdYlGn-10',
#          'type': 'diverging',
#          'category': 'ColorBrewer',
#          'colors': ['#006837',
#           '#1a9850',
#           '#66bd63',
#           '#a6d96a',
#           '#d9ef8b',
#           '#fee08b',
#           '#fdae61',
#           '#f46d43',
#           '#d73027',
#           '#a50026'],
#          'reversed': True},
#         'strokeColorRange': {'name': 'Global Warming',
#          'type': 'sequential',
#          'category': 'Uber',
#          'colors': ['#5A1846',
#           '#900C3F',
#           '#C70039',
#           '#E3611C',
#           '#F1920E',
#           '#FFC300']},
#         'radius': 10,
#         'sizeRange': [0, 10],
#         'radiusRange': [0, 50],
#         'heightRange': [0, 500],
#         'elevationScale': 5,
#         'stroked': False,
#         'filled': True,
#         'enable3d': False,
#         'wireframe': False},
#        'textLabel': [{'field': None,
#          'color': [255, 255, 255],
#          'size': 18,
#          'offset': [0, 0],
#          'anchor': 'start',
#          'alignment': 'center'}]},
#       'visualChannels': {'colorField': {'name': 'I1', 'type': 'integer'},
#        'colorScale': 'quantile',
#        'sizeField': None,
#        'sizeScale': 'linear',
#        'strokeColorField': None,
#        'strokeColorScale': 'quantile',
#        'heightField': None,
#        'heightScale': 'linear',
#        'radiusField': None,
#        'radiusScale': 'linear'}}],
#     'interactionConfig': {'tooltip': {'fieldsToShow': {'24645u33j': ['I1'],
#        'z4h7l9e4a': ['irwinid',
#         'mapmethod',
#         'unitIDProt',
#         'unitIDOwn',
#         'incidentID'],
#        'zbswxvdn': ['OBJECTID',
#         'SHAPE_Area',
#         'irwinid',
#         'mapmethod',
#         'unitIDProt'],
#        '786hup2i': ['Shape_Area',
#         'irwinid',
#         'mapmethod',
#         'unitIDProt',
#         'unitIDOwn'],
#        'tzehl3l3d': ['irwinid',
#         'mapmethod',
#         'unitIDProt',
#         'unitIDOwn',
#         'incidentID']},
#       'enabled': True},
#      'brush': {'size': 0.5, 'enabled': False}},
#     'layerBlending': 'additive',
#     'splitMaps': [],
#     'animationConfig': {'currentTime': None, 'speed': 1}},
#    'mapState': {'bearing': 0,
#     'dragRotate': False,
#     'latitude': 39.459222884936366,
#     'longitude': -121.26287270509843,
#     'pitch': 0,
#     'zoom': 7,
#     'isSplit': False},
#    'mapStyle': {'styleType': 'dark',
#     'topLayerGroups': {},
#     'visibleLayerGroups': {'label': True,
#      'road': True,
#      'border': False,
#      'building': True,
#      'water': True,
#      'land': True,
#      '3d building': False},
#     'threeDBuildingColor': [9.665468314072013,
#      17.18305478057247,
#      31.1442867897876],
#     'mapStyles': {}}}},
#  'info': {'app': 'kepler.gl',
#   'created_at': 'Sat Nov 23 2019 13:12:57 GMT+0100 (Central European Standard Time)'}}

# %%
# Initialise pandas dfs to hold the datasets
df1, df2, df3, df4, df5 = pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame()
dfs = [df1, df2, df3, df4, df5]

# Create a df for each dataset in turn
for dataset in range(5):
    
    # get actual data from json
    data = json_file['datasets'][dataset]['data']['allData']
    
    # turn into df
    dfs[dataset] = pd.DataFrame(data)
    
    # extract coordinates
    dfs[dataset].loc[:,'geometry'] = dfs[dataset][0].map(lambda x: x['geometry']['coordinates'][0])
    
    # create polygons in list
    if json_file['datasets'][dataset]['data']['allData'][0][0]['geometry']['type'] == 'Polygon':
        rows = dfs[dataset].geometry.to_list()    
        geometry = [Polygon(xy) for xy in rows]
        
        # drop columns we don't need
        dfs[dataset] = dfs[dataset].iloc[:,1:3]
    
        # rename columns
        dfs[dataset].columns = ['date', 'level']
        dfs[dataset].date = pd.to_datetime(dfs[dataset].date)
        
    # create geometry column based on structure of the individual datasets
    elif json_file['datasets'][dataset]['data']['allData'][0][0]['geometry']['type'] == 'MultiPolygon':
        rows = dfs[dataset].geometry[0]
        if len(rows) > 1:
            polygons = []
            for row in rows:
                polygons.append(Polygon(row))
            geometry = [MultiPolygon(polygons)]
            
        else: 
            geometry = [Polygon(xy) for xy in rows] 
    
    # Make sure to use the same crs throughout the project
    crs = {'init': 'epsg:4326'}

    # Create GDF
    dfs[dataset] = gpd.GeoDataFrame(dfs[dataset], crs=crs, geometry=geometry)

# %% [markdown]
# ### Inspect the hazard index data
#
# I begin my inspection with the main dataset that's in df1. It looks like we have 511870 pixel-time datapoints with a fire hazard index score. However, there seem to be some pixel-time points which we have to discard, because they have negative index values, which doesn't make sense.

# %%
# The hazard index data sits in the first df, the other dfs have the coordinates for the fires
main_df = dfs[0]
main_df
# Out:
#              date  level                                           geometry
# 0      2019-10-01      1  POLYGON ((-121.06779 42.05171, -121.06779 42.0...
# 1      2019-10-01      1  POLYGON ((-121.09860 42.04144, -121.09860 42.0...
# 2      2019-10-01      3  POLYGON ((-121.08833 42.04144, -121.08833 42.0...
# 3      2019-10-01      4  POLYGON ((-121.07806 42.04144, -121.07806 42.0...
# 4      2019-10-01      2  POLYGON ((-121.03699 42.04144, -121.03699 42.0...
# ...           ...    ...                                                ...
# 518865 2019-10-08      4  POLYGON ((-119.17861 36.91807, -119.17861 36.9...
# 518866 2019-10-08      3  POLYGON ((-119.16835 36.91807, -119.16835 36.9...
# 518867 2019-10-08      2  POLYGON ((-119.15808 36.91807, -119.15808 36.9...
# 518868 2019-10-08      1  POLYGON ((-119.33262 36.90780, -119.33262 36.8...
# 518869 2019-10-08 -32767  POLYGON ((-124.02477 42.10305, -124.02477 42.0...
#
# [518870 rows x 3 columns]

# %% [markdown]
# It looks like the index goes from 0 to 999.

# %%
main_df.describe()
# Out:
#         level
# count 518,870
# mean       41
# std     1,300
# min   -32,767
# 25%        12
# 50%        41
# 75%       112
# max       989

# %% [markdown]
# Let's discard the datapoints which have incorrect index values:

# %%
main_df[main_df.level < 0]
# Out:
#              date  level                                           geometry
# 1283   2019-10-01 -32767  POLYGON ((-121.10886 41.90797, -121.10886 41.8...
# 1420   2019-10-01 -32767  POLYGON ((-121.20127 41.88744, -121.20127 41.8...
# 2132   2019-10-01 -32767  POLYGON ((-122.59762 41.83610, -122.59762 41.8...
# 3517   2019-10-01 -32767  POLYGON ((-122.47441 41.77450, -122.47441 41.7...
# 3862   2019-10-01 -32767  POLYGON ((-122.25880 41.73343, -122.25880 41.7...
# ...           ...    ...                                                ...
# 516359 2019-10-08 -32767  POLYGON ((-119.71251 37.21582, -119.71251 37.2...
# 517515 2019-10-08 -32767  POLYGON ((-121.13967 37.08235, -121.13967 37.0...
# 517543 2019-10-08 -32767  POLYGON ((-121.75570 37.07208, -121.75570 37.0...
# 518203 2019-10-08 -32767  POLYGON ((-121.68383 36.98994, -121.68383 36.9...
# 518869 2019-10-08 -32767  POLYGON ((-124.02477 42.10305, -124.02477 42.0...
#
# [805 rows x 3 columns]

# %%
main_df = main_df[main_df.level > 0]

# %% [markdown]
# Just to get an idea of how this index is distributed, let's look at histograms. Also, let's compare the development of the index over the eight days we've got data for:

# %%
# Hazard index histograms per day
fig, axes = plt.subplots(nrows=1,ncols=8, figsize = (30, 3), sharex=True, sharey=True)
fig.subplots_adjust(hspace = 0.4)

for day in range(1,9,1):
    main_df[main_df.date == dt.datetime(2019, 10, day)].hist(bins = 50, ax = axes[day-1])
    axes[day-1].set(title = 'October ' + str(day), ylabel = 'frequency', xlabel = 'hazard level')

plt.tight_layout();
plt.show()

# %% [markdown]
# Difficult to tell the difference. Let's zoom in a bit:

# %%
# Hazard index histograms per day, zoomed
fig, axes = plt.subplots(nrows=1,ncols=8, figsize = (30, 3), sharex=True, sharey=True)
fig.subplots_adjust(hspace = 0.4)

for day in range(1,9,1):
    main_df[main_df.date == dt.datetime(2019, 10, day)].hist(bins = 50, ax = axes[day-1])
    axes[day-1].set(title = 'October ' + str(day), ylabel = 'frequency', xlabel = 'hazard level')

axes[0].set_xlim(400, 1000); axes[0].set_ylim(0, 200);
plt.tight_layout();
plt.show()

# %% [markdown]
# **Looks like the hazard is reducing a bit, at least the areas with very high risk seem to be reducing.**

# %% [markdown]
# ## Pick area of interest
#
# Now that we have a bit of an idea of the hazard index dataset, let's pick an area of interest:
# I will study an area around the Santa Rosa fire of 2017.

# %%
# Select the df of the Santa Rosa fire
fire_area = dfs[1].loc[:,['geometry']]
fire_area
# Out:
#                                             geometry
# 0  POLYGON ((-122.75937 38.52304, -122.75925 38.5...

# %%
# Have a look at the result
fire_area.plot()

# %% [markdown]
# We also want to include the area around the fire. Therefore, we pick the center of the fire and anything 50km above, below, to the left and right.

# %%
fire_centre = fire_area.centroid

# %%
# The centroid of the fire
fire_centre = (fire_centre[0].xy[1][0],fire_centre[0].xy[0][0])
fire_centre
# Out:
# (38.54696115613171, -122.68515427508606)

# %%
# 50km - just large enough to have interesting topological variation, and small enough to process on a laptop
distance = 50000

# %%
# Make a box around the centroid, 10000 sqkm
focus_area = ox.bbox_from_point(fire_centre, distance)
focus_area
# Out:
# (38.99753977362432, 38.09634767927647, -122.1114170328413, -123.25893542934972)

# %% [markdown]
# This is our area of interest:

# %%
# Create a Polygon, then a GeoSeries, which makes it easier to merge with GeoDataFrames
focus_area = Polygon([(focus_area[2], focus_area[0]), (focus_area[3], focus_area[0]), (focus_area[3], focus_area[1]), (focus_area[2], focus_area[1])])
focus_area_gdf = gpd.GeoSeries(focus_area, crs = crs)

# Check the result
focus_area_gdf.plot()

# %%
# Confirm we have the right crs
focus_area_gdf.crs
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# Now that we have identified a focus area, let's download some data for this area. A tool relied on by many for this is openstreetmaps.
# Other potential data sources on infrastructure, roads etc are of course available, but are often propietary or more time-consuming to access.
#
# # Import data on the topography from openstreetmaps

# %% [markdown]
# ## Roads
#
# Roads help us identify density, which is an important correlate with real estate prices.
#
# ### Download road data

# %%
# Download all roads accesible to cars in our area of interest
roads = ox.graph_from_point(fire_centre, distance, network_type='drive', simplify=False, retain_all=True)

# Have a look at the result
fig, ax = ox.plot_graph(roads)

# %% [markdown]
# ### Extract centrality measure
#
# A good proxy for real estate prices are network centrality measures. A simple way to get these for the road network graph in our area of interest, is to create a NetowrkX graph object.
# Many centrality measures could be tried. I'll have a go with Pagerank.

# %%
# Calculate centrality measures
roads_stats = ox.stats.extended_stats(roads)

# %%
# Which measures are available?
roads_stats.keys()

# %%
# let's save the pagerank measure
pagerank = roads_stats['pagerank']
pagerank

# %% [markdown]
# ### Store centrality measure results in geodataframe, for later merging with our main data

# %%
# Create GDFs from the Networkx graph
nodes, edges = ox.graph_to_gdfs(roads)

# %%
# Project it to our crs
edges = ox.project_gdf(edges, to_crs = crs)
nodes = ox.project_gdf(nodes, to_crs = crs)

# %%
# These are the edges
edges.head()

# %%
# These are the nodes
nodes.head()

# %%
# Join the pagerank measures to the nodes
nodes.loc[:,'pagerank'] = nodes.osmid.map(lambda x: pagerank[x])

# %%
# Have a look at the result
nodes.head()

# %%
# create df
nodes_df = nodes.loc[:,['geometry', 'pagerank']]

# %% [markdown]
# ## Buildings
#
# The area taken up by buildings is a good proxy of the value of property present in a certain pixel.
#
# ### Download building footprints

# %%
# Download all building footprints in our focus area
buildings = ox.footprints.footprints_from_point(fire_centre, distance, footprint_type='building')

# %%
# Have a look at the result
buildings.head()

# %%
# Which unique building types are there?
buildings.building.unique()

# %%
# Make sure we apply our project crs
buildings = ox.project_gdf(buildings, to_crs = crs)

# %%
# Have a look at the result
buildings.plot()

# %% [markdown]
# ### Extract building size / area of footprint

# %%
# Compute the area of building footprints
buildings_proj = ox.project_gdf(buildings)
areas = buildings_proj.area

# %% [markdown]
# ### Store building area results in geodataframe, for later merging with our main data

# %%
# join to geodataframe
buildings = buildings.assign(building_area = areas)

# reset index so we have a UID
buildings = buildings.reset_index()

# Rename columns
buildings = buildings.rename(columns = {'index' : 'ID'})

# Select only columns we will need later
buildings_df = buildings.loc[:,['ID', 'geometry', 'building', 'amenity', 'building_area']]

# %% [markdown]
# ## Points of interest
#
# Points of interest give us good information specifically on larger infrastructure, and allow us to introduce value categories.
#
# ### Download points of interest

# %%
# Download all POIs in our focus area
poi = ox.pois.pois_from_point(fire_centre, distance)

# %%
# Project to our project crs
poi = ox.project_gdf(poi, to_crs = crs)

# Clean out amenities without name and parkings
poi[(poi.amenity != 'parking') & (poi.amenity.notna())].head()

# %% [markdown]
# ### Extract values: Assign points of interest to value categories

# %%
# Extract all unique types of amenities included in dataset
poi_list = poi.amenity.unique().tolist()
poi_list

# %% [markdown]
# Mock data for the worth of these structures.

# %%
# Mock values
values = {'small' : 50000,
         'medium': 500000,
         'large' : 5000000}

# Let's start with assigning amenities to the medium type
medium_infrastructure = ['bar', 'restaurant', 'place_of_worship', 'post_office', 'fast_food', 'cafe',
       'pub', 'bank', 'veterinary', 'pharmacy','boat_rental', 'waste_disposal', 'ranger_station', 'dentist',
       'bicycle_rental', 'doctors', 'shelter', 'kindergarten', 'ice_cream', 'recycling', 'bicycle_repair_station',
       'marketplace', 'casino', 'studio', 'social_centre', 'childcare', 'nightclub', 'coworking_space', 
       'social_facility', 'food_court', 'tool_library', 'crematorium', 'office', 'bureau_de_change', 'courthouse', 
       'spa', 'scrapyard', 'trailer_park', 'monastery', 'planetarium', 'club', 'animal_shelter',
       'animal_boarding', 'music_school', 'events_venue']

# %%
# Check which amenities we haven't assigned yet
from itertools import compress
allocated = [poi not in medium_infrastructure for poi in poi_list]
list(compress(poi_list, allocated))

# %%
# Assign amenities to small type
small_infrastructure = ['parking',
                         'charging_station', 'toilets', 'bench', 'bicycle_parking', 'fountain', 'drinking_water',
                         'horse_water', 'vending_machine', 'post_box', 'atm', 'bus_station', 'sanitary_dump_station',
                         'parking_entrance', 'telephone', 'waste_basket', 'watering_place', 'compressed_air',
                         'dojo', 'clock', 'public_bookcase', 'shower', 'letter_box', 'weighbridge', 'car_pooling',
                         'parking_space', 'motorcycle_parking']

# %%
# Check which amenities we haven't assigned yet
from itertools import compress
allocated = [((poi not in medium_infrastructure) & (poi not in small_infrastructure)) for poi in poi_list]
list(compress(poi_list, allocated))

# %%
# Assign amenities to large type
large_infrastructure = ['fuel', 'school', 'grave_yard', 'theatre', 'hospital', 'college', 'community_centre', 'arts_centre',
                         'fire_station', 'library', 'prison', 'townhall', 'pool', 'police', 'ferry_terminal', 'clinic',
                         'swimming_pool', 'cinema', 'car_wash', 'loading_dock', 'music_venue', 'car_rental', 'public_building', 'university']

# %% [markdown]
# ### Store POI value categorisation in geodataframe, for later merging with our main data

# %%
# Throw out uninteresting columns
poi_df = poi[poi.amenity.notna()].loc[:,['osmid', 'geometry', 'amenity', 'name']]

# %%
# Join value to GDF
def assign_value(name, values):
    if name in small_infrastructure:
        value = values['small']
    elif name in medium_infrastructure:
        value = values['medium']
    elif name in large_infrastructure:
        value = values['large']
    else:
        value = None
    return value
        
poi_df.loc[:,'value'] = poi_df.amenity.map(lambda x: assign_value(x, values))

# %%
# Have a look at the result
poi_df.head()

# %% [markdown]
# ## Landuse
#
# Landuse categorisation let us identify whether there are farms or vineyards in the area that could be lost to a fire.
#
# ### Download land use data

# %%
# Download landuse
landuse = ox.footprints.footprints_from_point(fire_centre, distance = distance - 3000, footprint_type='landuse')

# %%
# Have a look at the result
landuse.head()

# %%
# Let's see which categories there are
landuse.landuse.unique()

# %%
# Make sure we have the correct crs
landuse = ox.project_gdf(landuse, to_crs = crs)

# %% [markdown]
# ### Extract farms, vineyards
#
# We will categorise two value categories of land use: farmland and winecountry. While there are more, we can easily group the high-value multi-year crops to winecountry and the lower value types to farmland.

# %%
# Low value types
farm_categories = ['farmyard', 'farmland', 'farm']

# %%
# High value types
vineyard_categories = ['vineyard', 'orchard', 'plant_nursery']

# %%
# Sort for farms
farmland = landuse[landuse.landuse.isin(farm_categories)]

# %%
# Have a look at the result
farmland.head()

# %%
# Sort for winecountry
winecountry = landuse[landuse.landuse.isin(vineyard_categories)]

# %%
# Have a look at the result
winecountry.head()

# %% [markdown]
# ### Store landuse categorisation in geodataframes, for later merging with our main data

# %%
farmland_df = farmland.loc[:,['geometry', 'landuse']]

# %%
winecountry_df = winecountry.loc[:,['geometry', 'landuse']]

# %%
farmland.plot()

# %%
winecountry.plot()

# %% [markdown]
# ## Plot our openstreetmap data
#
# Let's have a look at the spatial distribution of the data we just downloaded

# %%
# Make sure all dfs have the same crs
print(focus_area_gdf.crs, fire_area.crs, edges.crs, farmland.crs, winecountry.crs, buildings.crs, poi.crs)

# %%
fig, ax  = plt.subplots(figsize = (20, 20))

# Plot our focus area as background
focus_area_gdf.plot(ax = ax, facecolor='#a6aba2')

# Include the fire area
fire_area.plot(ax = ax, facecolor='r', alpha = 0.5)

# Plot street edges
edges.plot(ax=ax, linewidth=0.5, edgecolor='g', alpha  = 0.7)

# Plot wineyard and high value crops
winecountry.plot(ax=ax, facecolor='purple')

# Plot farmland and low value crops
farmland.plot(ax=ax, facecolor='pink')

# Plot buildings
buildings.plot(ax=ax, facecolor='y')

# Plot points of interest
poi.plot(ax=ax, color='w', markersize=20)

plt.tight_layout()

# %% [markdown]
# # Spatial merging datasets
#
# Spatial merge the hazard index grid with the points and polygons with economic measures attached to them that we extracted from openstreetmaps.
#
# ### Restrict the main data to a single day

# %%
main_df.count()

# %%
# Reduce to first day to reduce the amount of data for thes processing heavy joins
main_df_raw = main_df
main_df = main_df[main_df.date == dt.datetime(2019, 10, 1)]

# %%
main_df.count()

# %% [markdown]
# ### merge main data + buildings

# %%
# have a look at the data to be merged
buildings_df.head()

# %%
# merge
hazard_joined = gpd.sjoin(main_df, buildings_df, how='left', op='intersects')

# %%
# drop unnecessary var
hazard_joined = hazard_joined.drop(columns = 'index_right')

# %% [markdown]
# ### add points of interest

# %%
# have a look at the data to be merged
poi_df.head()

# %%
# merge
hazard_joined = gpd.sjoin(hazard_joined, poi_df, how='left', op='intersects')

# %%
# drop unnecessary var
hazard_joined = hazard_joined.drop(columns = 'index_right')

# %% [markdown]
# ### add farmland

# %%
# have a look at the data to be merged
farmland_df.head()

# %%
# merge
hazard_joined = gpd.sjoin(hazard_joined, farmland_df, how='left', op='intersects')

# %%
# drop unnecessary var
hazard_joined = hazard_joined.drop(columns = 'index_right')

# %% [markdown]
# ### add winecountry

# %%
# have a look at the data to be merged
winecountry_df.head()

# %%
# merge
hazard_joined = gpd.sjoin(hazard_joined, winecountry_df, how='left', op='intersects', rsuffix = 'wine')

# %%
# drop unnecessary var
hazard_joined = hazard_joined.drop(columns = 'index_wine')

# %% [markdown]
# ### add centrality

# %%
# have a look at the data to be merged
nodes.head()

# %%
# merge
hazard_joined = gpd.sjoin(hazard_joined, nodes_df, how='left', op='intersects')

# %%
# Have a look at the results from our merges
hazard_joined.head()

# %% [markdown]
# # Aggregate economic measures by pixel grid
#
# Aggregation by pixel UID:
# - Take the first value for columns we got from our main dataset (they are all the same, since we merged multiple objects to the same pixel)
# - Count the landuse columns: there will only be one classification per pixel, most likely.
# - Sum the value, building area and pagerank columns: These are measures that will have a close correlation with

# %%
# Aggregation
hazard_joined_agg = hazard_joined.groupby(hazard_joined.index).agg(geometry = ('geometry', 'first'), 
                                                                   level = ('level', 'first'),
                                                                   date = ('date', 'first'),
                                                                   farm = ('landuse_left', 'count'),
                                                                   wine = ('landuse_wine', 'count'),
                                                                   poi_value = ('value', 'sum'),
                                                                   building_area = ('building_area', 'sum')
                                                                   pagerank = ('pagerank', 'sum'))

# %%
hazard_joined_agg_gdf = gpd.GeoDataFrame(hazard_joined_agg, geometry = 'geometry')

# %%
hazard_joined_agg_gdf

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots(nrows=1,ncols=1, figsize = (10, 10))

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

hazard_joined_agg_gdf.plot(column='level', ax=ax, legend=True, cax=cax)

ax.set_title('Hazard level')

plt.show()

# %%
fig, ax = plt.subplots(nrows=1,ncols=1, figsize = (10, 10))

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

hazard_joined_agg_gdf[hazard_joined_agg_gdf.poi_value > 0].plot(column='poi_value', ax=ax, legend=True, cax=cax)

ax.set_title('Poi value')

plt.show()
